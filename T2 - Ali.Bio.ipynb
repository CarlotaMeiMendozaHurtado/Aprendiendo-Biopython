# %% [markdown]
#  <div class="alert alert-success">
# <b> Ejercicio 1: </b> Crea un alineador con las siguientes características:
# <ul>
# <li>Penalización por gap: -14</li>
# <li>Alineamiento global.</li>
# <li>Matriz de sustitución:</li>
# <table>
#   <thead>
#     <tr>
#       <th></th>
#       <th><strong>A</strong></th>
#       <th><strong>T</strong></th>
#       <th><strong>C</strong></th>
#       <th><strong>G</strong></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th><strong>A</strong></th>
#       <td>5</td>
#       <td>-2</td>
#       <td>-3</td>
#       <td>-11</td>
#     </tr>
#     <tr>
#       <th><strong>T</strong></th>
#       <td>-2</td>
#       <td>2</td>
#       <td>0</td>
#       <td>-13</td>
#     </tr>
#     <tr>
#       <th><strong>C</strong></th>
#       <td>-3</td>
#       <td>0</td>
#       <td>12</td>
#       <td>-5</td>
#     </tr>
#     <tr>
#       <th><strong>G</strong></th>
#       <td>-11</td>
#       <td>-13</td>
#       <td>-5</td>
#       <td>20</td>
#     </tr>
#   </tbody>
# </table>
# </ul>
#
# Imprime
# <ul>
#   <li>El propio objeto alineador.</li>
#   <li>La matriz de sustitución del alineador.</li>
#   <li>El algoritmo que utilizará el alineador.</li>
# </ul>
# </div>

# %%
from Bio import Align
from Bio.Align import PairwiseAligner
from Bio.Align import substitution_matrices



alineador = PairwiseAligner()
alineador.mode = "global"
alineador.open_gap_score = -14
alineador.extend_gap_score = -14


letras = "ATCG"
matriz = {
    ("A", "A"): 5,  ("A", "T"): -2, ("A", "C"): -3, ("A", "G"): -11,
    ("T", "A"): -2, ("T", "T"): 2,  ("T", "C"): 0,  ("T", "G"): -13,
    ("C", "A"): -3, ("C", "T"): 0,  ("C", "C"): 12, ("C", "G"): -5,
    ("G", "A"): -11,("G", "T"): -13,("G", "C"): -5, ("G", "G"): 20}
alineador.substitution_matrix = matriz
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 19
#      13 letras = "ATCG"
#      14 matriz = {
#      15     ("A", "A"): 5,  ("A", "T"): -2, ("A", "C"): -3, ("A", "G"): -11,
#      16     ("T", "A"): -2, ("T", "T"): 2,  ("T", "C"): 0,  ("T", "G"): -13,
#      17     ("C", "A"): -3, ("C", "T"): 0,  ("C", "C"): 12, ("C", "G"): -5,
#      18     ("G", "A"): -11,("G", "T"): -13,("G", "C"): -5, ("G", "G"): 20}
# ---> 19 alineador.substitution_matrix = matriz
#
# File c:\Users\aluCa\miniconda3\envs\biopy\Lib\site-packages\Bio\Align\__init__.py:3955, in PairwiseAligner.__setattr__(self, key, value)
#    3950 if key not in dir(_pairwisealigner.PairwiseAligner):
#    3951     # To prevent confusion, don't allow users to create new attributes.
#    3952     # On CPython, __slots__ can be used for this, but currently
#    3953     # __slots__ does not behave the same way on PyPy at least.
#    3954     raise AttributeError("'PairwiseAligner' object has no attribute '%s'" % key)
# -> 3955 _pairwisealigner.PairwiseAligner.__setattr__(self, key, value)
#
# ValueError: expected a matrix

# %%
print(matriz)
# Out:
# {('A', 'A'): 5, ('A', 'T'): -2, ('A', 'C'): -3, ('A', 'G'): -11, ('T', 'A'): -2, ('T', 'T'): 2, ('T', 'C'): 0, ('T', 'G'): -13, ('C', 'A'): -3, ('C', 'T'): 0, ('C', 'C'): 12, ('C', 'G'): -5, ('G', 'A'): -11, ('G', 'T'): -13, ('G', 'C'): -5, ('G', 'G'): 20}

# %% [markdown]
#  <div class="alert alert-success">
# <b> Ejercicio 2: </b> Utiliza el alineador que has creado con las secuencias del fichero `ejercicio1.fasta`. Contiene 10 secuencias. Debes comparar la primera con las otras nueve.
#
# Imprime:
# <ul>
#     <li> El alineamiento para cada par de secuencias. </li>
#     <li> Su puntuación. </li>
# </ul>
#
#
# </div>
